# %%
import kaggle
import pandas as pd

# %%
#!kaggle datasets -d download mlg-ulb/creditcardfraud  creditcard.csv
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# creditcardfraud.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref=zipfile.ZipFile("creditcard.csv.zip")
zip_ref.extractall()
zip_ref.close()

# %%
df=pd.read_csv("creditcard.csv")

# %%
pd.options.display.max_columns=None

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
df.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284797 -1.343668  0.929369 -0.206210  0.106234 -0.284708 -0.612982 -0.066655
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
print("Number of rows",df.shape[0])
print("Number of cols",df.shape[1])
# Out:
# Number of rows 284807
# Number of cols 31

# %%
#applying Standard Scalar
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df=df.drop(["Time"],axis=1)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
df.duplicated().any()
# Out:
# True

# %%
df=df.drop_duplicates()
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
df.shape
# Out:
# (275663, 30)

# %%
#NOT HANDLING IMBALABCED

# %%
df['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df["Class"])
# Out:
# C:\Users\chenn\anaconda3.2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
x=df.drop(['Class'],axis=1)
y=df['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
#predicting and testing

# %%
from sklearn.model_selection  import  train_test_split
x_train, x_test, y_train, y_test  =  train_test_split ( x, y, test_size=0.2, random_state=42 )

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(x_test)

# %%
#Metrices
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.9992200678359603

# %%
precision_score(y_test, y_pred1)
# Out:
# 0.8870967741935484

# %%
recall_score(y_test, y_pred1)
# Out:
# 0.6043956043956044

# %%
f1_score(y_test, y_pred1)
# Out:
# 0.718954248366013

# %%
#Handling imbalanced using undersampling ,oversampling

# %%
non_fraud=df[df['Class']==0]
fraud=df[df['Class']==1]

# %%
non_fraud.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal=normal.sample(n=473)

# %%
normal.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal,fraud])

# %%
new_data
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 281621 -1.716982  0.915604  0.498266 -0.989226  0.278409  2.079006 -0.767679
# 205490 -1.721558  0.600797 -1.432563 -1.199250  2.042059  3.544298 -0.933465
# 44997   1.211968  0.432028 -0.387191  0.878170 -0.076109 -1.170735  0.204825
# 223511  1.348286 -2.491870 -1.098396 -0.592656 -1.539385 -0.286151 -0.618956
# 168972 -0.402673  0.758772 -3.530115  0.500281  0.248259 -1.683530  2.844087
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
new_data.head(5)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 281621 -1.716982  0.915604  0.498266 -0.989226  0.278409  2.079006 -0.767679
# 205490 -1.721558  0.600797 -1.432563 -1.199250  2.042059  3.544298 -0.933465
# 44997   1.211968  0.432028 -0.387191  0.878170 -0.076109 -1.170735  0.204825
# 223511  1.348286 -2.491870 -1.098396 -0.592656 -1.539385 -0.286151 -0.618956
# 168972 -0.402673  0.758772 -3.530115  0.500281  0.248259 -1.683530  2.844087
#
#               V8        V9       V10       V11       V12       V13       V14  \
# 281621  1.602060 -0.086108 -0.905884  0.806419  1.264149  0.271802  0.449695
# 205490  2.035297 -0.013333 -1.206083 -0.115327  0.140352 -0.099234 -0.680356
# 44997  -0.098885  0.084044 -0.589446  0.322225 -0.830000 -1.905677 -0.613500
# 223511 -0.114153  0.315217  0.597283 -1.466852 -1.388721 -0.794288 -0.153284
# 168972 -0.312153 -0.562379 -1.556274 -0.591132 -0.705577 -0.913523 -0.986337
#
# ...

# %%
x=new_data.drop(['Class'],axis=1)
y=new_data['Class']

# %%
#predicting and testing

# %%
from sklearn.model_selection  import  train_test_split
x_train, x_test, y_train, y_test  =  train_test_split ( x, y, test_size=0.2, random_state=42 )

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.9473684210526315

# %%
precision_score(y_test, y_pred1)
# Out:
# 0.9893617021276596

# %%
recall_score(y_test, y_pred1)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test, y_pred1)
# Out:
# 0.9489795918367346

# %%
#USING DECISIONN TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.9368421052631579

# %%
precision_score(y_test, y_pred2)
# Out:
# 0.9326923076923077

# %%
recall_score(y_test, y_pred2)
# Out:
# 0.9509803921568627

# %%
f1_score(y_test, y_pred2)
# Out:
# 0.9417475728155339

# %%
#RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(x_test)

# %%
accuracy_score(y_test, y_pred3)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test, y_pred3)
# Out:
# 0.9680851063829787

# %%
recall_score(y_test, y_pred3)
# Out:
# 0.8921568627450981

# %%
f1_score(y_test, y_pred3)
# Out:
# 0.9285714285714286

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF'],"Accuracy":[accuracy_score(y_test, y_pred1)*100,
                                                   accuracy_score(y_test, y_pred2)*100,accuracy_score(y_test, y_pred3)*100]})

# %%
final_data
# Out:
#   Models   Accuracy
# 0     LR  94.736842
# 1     DT  93.684211
# 2     RF  92.631579

# %%
sns.barplot(final_data['Models'],final_data['Accuracy'])
# Out:
# C:\Users\chenn\anaconda3.2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='Accuracy'>

# %%
#------------OVERSAMPLING

# %%
x=df.drop(['Class'],axis=1)
y=df['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE

# %%
x_res , y_res = SMOTE().fit_resample(x,y)

# %%
y_res.shape
# Out:
# (550380,)

# %%
x_res.shape
# Out:
# (550380, 29)

# %%
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: Class, dtype: int64

# %%
x_res.value_counts()
# Out:
# V1          V2          V3         V4          V5          V6          V7          V8         V9         V10        V11        V12        V13        V14        V15        V16        V17        V18        V19        V20         V21        V22        V23        V24        V25        V26        V27        V28         Amount
# -56.407510  -72.715728  -6.605265   16.491217   34.801666  -26.160506  -19.399981  -1.501300   6.967698   9.537780   3.089395   1.776452   3.732744  -2.530792   5.784514   3.903988  -1.929314   0.206699   2.805883  -12.360962  -6.266878  -1.272167   7.893082   0.767805   5.376595   0.163672  -8.358317   33.847808   4.451791    1
#  0.214230    3.016931   -4.281900   4.532672    3.279799   -1.854571    1.349640   -1.284004  -2.340222  -1.709554   2.472157  -1.876449  -1.161455  -7.396322  -0.327264   2.828688   5.974491   3.343359  -2.413894  -0.274357    0.866975  -0.557950   0.159946  -0.789558  -0.486879   0.149439   0.059573   0.139005   -0.350283    1
# ...

# %%
from sklearn.model_selection  import  train_test_split
x_train, x_test, y_train, y_test  =  train_test_split ( x_res, y_res, test_size=0.2, random_state=42 )

# %%
#OVERSAMPLING LOGISTIC REGRESSION

# %%
log=LogisticRegression()
log.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predo1=log.predict(x_test)

# %%
accuracy_score(y_test, y_predo1)
# Out:
# 0.9451742432501181

# %%
precision_score(y_test, y_predo1)
# Out:
# 0.973047644808532

# %%
recall_score(y_test, y_predo1)
# Out:
# 0.9156409650382706

# %%
f1_score(y_test, y_predo1)
# Out:
# 0.9434718670675621

# %%
#OVERSAMPLING DECISION TREE

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predo2=dt.predict(x_test)

# %%
accuracy_score(y_test, y_predo2)
# Out:
# 0.9982375813074603

# %%
precision_score(y_test, y_predo2)
# Out:
# 0.9972239862106504

# %%
recall_score(y_test, y_predo2)
# Out:
# 0.9992545861134847

# %%
f1_score(y_test, y_predo2)
# Out:
# 0.9982382535098713

# %%
#OVERSAMPLING RANDOM FOREST

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predo3=dt.predict(x_test)

# %%
accuracy_score(y_test, y_predo3)
# Out:
# 0.9982375813074603

# %%
precision_score(y_test, y_predo3)
# Out:
# 0.9972239862106504

# %%
recall_score(y_test, y_predo3)
# Out:
# 0.9992545861134847

# %%
f1_score(y_test, y_predo3)
# Out:
# 0.9982382535098713

# %%
final_data_over=pd.DataFrame({'Models':['LR','DT','RF'],"Accuracy":[accuracy_score(y_test, y_predo1)*100,
                                                   accuracy_score(y_test, y_predo2)*100,accuracy_score(y_test, y_predo3)*100]})

# %%
final_data_over
# Out:
#   Models   Accuracy
# 0     LR  94.517424
# 1     DT  99.823758
# 2     RF  99.823758

# %%
sns.barplot(final_data_over['Models'],final_data['Accuracy'])
# Out:
# C:\Users\chenn\anaconda3.2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='Accuracy'>

# %%
import joblib

# Load the pre-trained model
model = joblib.load("credit_card_model")

# The input data should be reshaped into a 2D array (1 sample, multiple features)
#input_data = [1.359807,-0.072781,2.536347,1.378155,-0.338321,0.462388,0.239599,0.098698,0.363787,0.090794,-0.551600,-0.617801,-0.991390,-0.311169,1.468177,-0.470401,0.207971,0.025791,0.403993,0.251412,-0.018300,0.277838,-0.110474,0.066928,0.128539,-0.189115,0.133558,-0.021053,0.2449644]
input_data=[-2.312227 , 1.951992 , -1.609851 , 3.997906 ,-0.522188 ,-1.426545 ,-2.537387 , 1.391657 ,-2.770089, -2.772272 , 3.202033  ,-2.899907 ,-0.595222, -4.289254 , 0.389724 ,-1.140747 , -2.830056 ,-0.016822 , 0.416956 , 0.126911  ,0.517232, -0.035049, -0.465211  ,0.320198 , 0.044519 , 0.177840 , 0.261145, -0.143276 ,-0.353229] 
# Reshape the input to be 2D: 1 row and len(input_data) columns
input_data_reshaped = [input_data]  # This turns it into a 2D array

# Predict using the reshaped input
pred = model.predict(input_data_reshaped)

# Interpret and print the result
if pred == 0:
    print("Non fraud")
else:
    print("Fraud")
# Out:
# Fraud
# C:\Users\chenn\anaconda3.2\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# Adjust display width to show more columns horizontally
pd.set_option('display.width', 1000)  # You can set the value higher if needed
pd.set_option('display.max_columns', None)  # Ensure all columns are displayed

# Retrieve rows where class equals 1
class_1_rows = df[df['Class'] == 1]

# Display the rows
print(class_1_rows)
# Out:
#               V1        V2        V3        V4        V5        V6        V7        V8        V9       V10       V11        V12       V13       V14       V15       V16        V17       V18       V19       V20       V21       V22       V23       V24       V25       V26       V27       V28    Amount  Class
# 541    -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387  1.391657 -2.770089 -2.772272  3.202033  -2.899907 -0.595222 -4.289254  0.389724 -1.140747  -2.830056 -0.016822  0.416956  0.126911  0.517232 -0.035049 -0.465211  0.320198  0.044519  0.177840  0.261145 -0.143276 -0.353229      1
# 623    -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574 -0.067794 -0.270953 -0.838587 -0.414575  -0.503141  0.676502 -1.692029  2.000635  0.666780   0.599717  1.725321  0.283345  2.102339  0.661696  0.435477  1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764  1.761758      1
# ...
